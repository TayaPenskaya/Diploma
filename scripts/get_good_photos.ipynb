# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt

# %%
mypath = '../data/fashion1024/fashion1024'

# %%
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
good_ids_standing = [2, 3, 29, 36, 40, 48, 57, 69, 75, 137]

good_ids_walking = [14, 19, 20, 25, 30, 50, 55, 72, 85]

good_ids_sitting = [22, 79, 98]

good_ids_lying = [68]

# %%
for i in good_ids_standing:
    #plt.figure()
    print(join(mypath, onlyfiles[i]))
    #pil_im = Image.open(join(mypath, onlyfiles[i]), 'r')
    #imshow(np.asarray(pil_im))
# Out:
# ../data/fashion1024/fashion1024/19355086f297de7284cd5a32ea1706ff.jpg
# ../data/fashion1024/fashion1024/1d8b723643da1124b4ef3ccae56bc4b8.jpg
# ../data/fashion1024/fashion1024/7604cc62f5feb5f192381466995efd03.jpg
# ../data/fashion1024/fashion1024/9b6de4aa1f3cfb9bf28c8cb08998d1ce.jpg
# ../data/fashion1024/fashion1024/bed0cbceb4de619ec396e274612aed11.jpg
# ../data/fashion1024/fashion1024/86504cd9e6e797427afedfd16cdf27a7.jpg
# ../data/fashion1024/fashion1024/d03d8df6677f550ead643e655c5e5677.jpg
# ../data/fashion1024/fashion1024/c9ef65053aaabc99c4069e143a5382e0.jpg
# ../data/fashion1024/fashion1024/9a266ee0e4c8f8f20a8f2b59fd38192d.jpg
# ../data/fashion1024/fashion1024/b6995195f15ee9eb25f82ff170985122.jpg

# %%
fig = plt.figure(figsize=(16,8), dpi=140)

plt.subplot(131)
plt.axis('off')
pil_im = Image.open(join(mypath, onlyfiles[2122]), 'r')
plt.imshow(np.asarray(pil_im))

plt.subplot(132)
plt.axis('off')
pil_im = Image.open(join(mypath, onlyfiles[1585]), 'r')
plt.imshow(np.asarray(pil_im))


plt.subplot(133)
plt.axis('off')
pil_im = Image.open(join(mypath, onlyfiles[125]), 'r')
plt.imshow(np.asarray(pil_im))

fig.savefig("../data/fashion1024/test/1.jpg")
